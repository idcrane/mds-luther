# %%
from bs4 import BeautifulSoup
import urllib2
gmail_url = "http://mail.google.com"

soup = BeautifulSoup(urllib2.urlopen(gmail_url).read())
print soup.prettify()
# Out:
# <html>
#  <head>
#   <meta content="0;URL=http://mail.google.com/mail/" http-equiv="Refresh"/>
#  </head>
#  <body>
#   <script language="javascript" type="text/javascript">
#    <!--
# location.replace("http://mail.google.com/mail/")
# -->
#   </script>
#  </body>
# </html>

# %%
new_url = 'http://mail.google.com/mail/'
soup = BeautifulSoup(urllib2.urlopen(new_url).read())

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8">
#    <meta content="width=300, initial-scale=1" name="viewport">
#     <meta content="Gmail is email that's intuitive, efficient, and useful. 15 GB of storage, less spam, and mobile access." name="description">
#      <title>
#       Gmail
#      </title>
#      <style>
#       @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 300;
#   src: local('Open Sans Light'), local('OpenSans-Light'), url(//fonts.gstatic.com/s/opensans/v10/DXI1ORHCpsQm3Vp6mXoaTYnF5uFdDttMLvmWuJdhhgs.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 400;
#   src: local('Open Sans'), local('OpenSans'), url(//fonts.gstatic.com/s/opensans/v10/cJZKeOuBrn4kERxqtaUH3aCWcynf_cDxXwCLxiixG1c.ttf) format('truetype');
# }
#      </style>
#      <style>
#       h1, h2 {
#   -webkit-animation-duration: 0.1s;
#   -webkit-animation-name: fontfix;
# ...

# %%
print soup.find(id="Email")
# Out:
# <input class="" id="Email" name="Email" placeholder="Email" spellcheck="false" type="email" value="">
# <label class="hidden-label" for="Passwd">Password</label>
# <input class="" id="Passwd" name="Passwd" placeholder="Password" type="password">
# <input class="rc-button rc-button-submit" id="signIn" name="signIn" type="submit" value="Sign in">
# <input name="PersistentCookie" type="hidden" value="yes">
# <a href="https://accounts.google.com/RecoverAccount?service=mail&amp;continue=http%3A%2F%2Fmail.google.com%2Fmail%2F" id="link-forgot-passwd">
#   Need help?
#   </a>
# </input></input></input></input>

# %%
from selenium import webdriver

# %%
from selenium.webdriver.common.keys import Keys

# %%
chrome = webdriver.Chrome('./chromedriver')

# %%
gmail_url = "https://mail.google.com"
chrome.get(gmail_url)

# %%
username_form = chrome.find_element_by_id('Email')
username_form.send_keys("irmak.hacker")

# %%
password_form = chrome.find_element_by_id('Passwd')
password_form.send_keys("timdsbcpw")

# %%
password_form.send_keys(Keys.RETURN)

# %%
# xpath is way to navigate webpages, has its own syntax
compose_button = chrome.find_element_by_xpath('//div[text()="COMPOSE"]')
compose_button.click()

# %%
to_filed = chrome.find_element_by_name("to")
to_field.send_keys("irmak@datasco.pe")

subject = chrome.find_element_by_name("subjectbox")
subject.send_keys("Skynet imminent")

message_body = chrome.find_element_by_id(":ak")
message_body.send_keys("Hellow",Keys.RETURN, Keys.RETURN)
message_body.send_keys("I am a computer and I just became aware")

# %%
send_button = chrome.find_element_by_id(':98')
send_button.click()

# %%
chrome.close()

# %%
matrix_urls = "http://www.boxofficemojo.com/movies/?id=matrix.htm"
chrome.get(matrix_urls)

# %%
# the /b says give you the b element under what you just found
gross_selector = '//font[contains(text(), "Domestic Total")]/b'
print chrome.find_element_by_xpath(gross_selector).text
# Out:
# $171,479,930

# %%
genre_selector = '//a[contains(@href, "/genres/chart")]'
all_genre_links = chrome.find_elements_by_xpath(genre_selector)
for genre_link in all_genre_links:
    print genre_link.text
# Out:
# Action - Wire-Fu
# Man vs. Machine
# Virtual Reality

# %%
inf_adjust_selector = '//select[@name="ticketyr"]/option[@value="2000"]'
chrome.find_element_by_xpath(inf_adjust_selector).click()

# %%
go_button = chrome.find_element_by_name("Go")
go_button.click()

# %%
print chrome.find_element_by_xpath(gross_selector).text
# Out:
# $181,944,300

# %%
chrome.close()
